# %%
import numpy as np


class NaiveBayes:
    def fit(self, X, y):
        n_samples, n_features = X.shape
        self._classes = np.unique(y)
        n_classes = len(self._classes)

        # calculate mean, var, and prior for each class
        self._mean = np.zeros((n_classes, n_features), dtype=np.float64)
        self._var = np.zeros((n_classes, n_features), dtype=np.float64)
        self._priors = np.zeros(n_classes, dtype=np.float64)

        for idx, c in enumerate(self._classes):
            X_c = X[y == c]
            self._mean[idx, :] = X_c.mean(axis=0)
            self._var[idx, :] = X_c.var(axis=0)
            self._priors[idx] = X_c.shape[0] / float(n_samples)

    def predict(self, X):
        y_pred = [self._predict(x) for x in X]
        return np.array(y_pred)

    def _predict(self, x):
        posteriors = []

        # calculate posterior probability for each class
        for idx, c in enumerate(self._classes):
            prior = np.log(self._priors[idx])
            posterior = np.sum(np.log(self._pdf(idx, x)))
            posterior = prior + posterior
            posteriors.append(posterior)

        # return class with highest posterior probability
        return self._classes[np.argmax(posteriors)]

    def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        numerator = np.exp(-((x - mean) ** 2) / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        return numerator / denominator


# Testing
# if __name__ == "__main__":
#     # Imports

from sklearn.model_selection import train_test_split
from sklearn import datasets

def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

X, y = datasets.make_classification(
    n_samples=1000, n_features=10, n_classes=2, random_state=123
)
dataset = 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

nb = NaiveBayes()
nb.fit(X_train, y_train)
predictions = nb.predict(X_test)

print("Naive Bayes classification accuracy", accuracy(y_test, predictions))

# %% [markdown]
# ## Fit model

# %%
def fit(self, X, y):
        n_samples, n_features = X.shape
        self._classes = np.unique(y)
        n_classes = len(self._classes)

        # calculate mean, var, and prior for each class
        self._mean = np.zeros((n_classes, n_features), dtype=np.float64)
        self._var = np.zeros((n_classes, n_features), dtype=np.float64)
        self._priors = np.zeros(n_classes, dtype=np.float64)

        for idx, c in enumerate(self._classes):
            X_c = X[y == c]
            self._mean[idx, :] = X_c.mean(axis=0)
            self._var[idx, :] = X_c.var(axis=0)
            self._priors[idx] = X_c.shape[0] / float(n_samples)

# %% [markdown]
# ## Predict

# %%
def predict(self, X):
        y_pred = [self._predict(x) for x in X]
        return np.array(y_pred)

# %%
def _predict(self, x):
    posteriors = []

    # calculate posterior probability for each class
    for idx, c in enumerate(self._classes):
        prior = np.log(self._priors[idx])
        posterior = np.sum(np.log(self._pdf(idx, x)))
        posterior = prior + posterior
        posteriors.append(posterior)

    # return class with highest posterior probability
    return self._classes[np.argmax(posteriors)]

# %%
def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        numerator = np.exp(-((x - mean) ** 2) / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        return numerator / denominator

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

# %%
import pandas as pd

dataset = df = pd.read_csv("iniDsNaive.csv", delimiter='\t')
df.head()
# Out:
#    No.  JK  UMUR  X1  X2  X3  X4  X5  X6  X7  ...  X9  X10  X11  X12  X13  \
# 0    1   1    19   3   1   3   3   1   3   1  ...   1    1    1    3    3
# 1    2   0    22   1   2   2   1   1   3   1  ...   1    1    1    1    2
# 2    3   0    23   3   2   2   1   2   2   1  ...   2    1    1    1    2
# 3    4   0    20   3   3   3   3   2   3   3  ...   2    2    2    2    2
# 4    5   1    22   3   3   3   3   3   3   2  ...   2    1    3    3    3
#
#    X14  X15  X16  X17  KELAS
# 0    3    3    3    2      1
# 1    1    1    1    1      1
# 2    2    2    2    1      2
# 3    2    2    2    1      2
# 4    3    3    3    3      3
#
# [5 rows x 21 columns]

# %%
import numpy as np
class NaiveBayes:
    def fit(self, X, y):
        n_samples, n_features = X.shape
        self._classes = np.unique(y)
        n_classes = len(self._classes)

        # calculate mean, var, and prior for each class
        self._mean = np.zeros((n_classes, n_features), dtype=np.float64)
        self._var = np.zeros((n_classes, n_features), dtype=np.float64)
        self._priors = np.zeros(n_classes, dtype=np.float64)

        for idx, c in enumerate(self._classes):
            X_c = X[y == c]
            self._mean[idx, :] = X_c.mean(axis=0)
            self._var[idx, :] = X_c.var(axis=0)
            self._priors[idx] = X_c.shape[0] / float(n_samples)

    def predict(self, X):
        y_pred = [self._predict(x) for x in X]
        return np.array(y_pred)

    def _predict(self, x):
        posteriors = []

        # calculate posterior probability for each class
        for idx, c in enumerate(self._classes):
            prior = np.log(self._priors[idx])
            posterior = np.sum(np.log(self._pdf(idx, x)))
            posterior = prior + posterior
            posteriors.append(posterior)

        # return class with highest posterior probability
        return self._classes[np.argmax(posteriors)]

    def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        numerator = np.exp(-((x - mean) ** 2) / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        return numerator / denominator

# %%
inputs = df.drop('KELAS',axis='columns')
label = df['KELAS']

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, label, test_size=0.2, random_state=123)

# %%
nb = NaiveBayes()
nb.fit(X_train, y_train)
predictions = nb.predict(X_test)

print("Naive Bayes classification accuracy", accuracy(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2700/1200225025.py in <module>
#       1 nb = NaiveBayes()
#       2 nb.fit(X_train, y_train)
# ----> 3 predictions = nb.predict(X_test)
#       4
#       5 print("Naive Bayes classification accuracy", accuracy(y_test, predictions))
#
# ~\AppData\Local\Temp/ipykernel_2700/4173578570.py in predict(self, X)
#      18
#      19     def predict(self, X):
# ---> 20         y_pred = [self._predict(x) for x in X]
#      21         return np.array(y_pred)
#      22
#
# ~\AppData\Local\Temp/ipykernel_2700/4173578570.py in <listcomp>(.0)
#      18
#      19     def predict(self, X):
# ---> 20         y_pred = [self._predict(x) for x in X]
#      21         return np.array(y_pred)
#      22
#
# ~\AppData\Local\Temp/ipykernel_2700/4173578570.py in _predict(self, x)
#      27         for idx, c in enumerate(self._classes):
#      28             prior = np.log(self._priors[idx])
# ---> 29             posterior = np.sum(np.log(self._pdf(idx, x)))
#      30             posterior = prior + posterior
#      31             posteriors.append(posterior)
#
# ~\AppData\Local\Temp/ipykernel_2700/4173578570.py in _pdf(self, class_idx, x)
#      37         mean = self._mean[class_idx]
#      38         var = self._var[class_idx]
# ---> 39         numerator = np.exp(-((x - mean) ** 2) / (2 * var))
#      40         denominator = np.sqrt(2 * np.pi * var)
#      41         return numerator / denominator
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U3'), dtype('float64')) -> None
